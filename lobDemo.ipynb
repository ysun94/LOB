# %%
from enum import Enum
import heapq

# %%
class Direction(Enum):
    buy = 0
    sell = 1

# %% [markdown]
# ### Define a class representing orders

# %%
class Order(object):
    def __init__(self, order_id, quantity, broker, timestamp, direction):
        self.order_id = order_id
        self.quantity = quantity
        self.broker = broker
        self.timestamp = timestamp
        self.direction = direction

    def get_order_id(self):
        return self.order_id

    def get_broker(self):
        return self.broker

    def get_timestamp(self):
        return self.timestamp

    def get_direction(self):
        return self.direction

    def get_quantity(self):
        return self.quantity

# %% [markdown]
# ### Define a subclass of Order representing limit orders
#    - The attributes in the class LimitOrder are slight different from those in Order, since in the limit order book the prices of orders must be specified.

# %%
class LimitOrder(Order):
    def __init__(self, order_id, quantity, broker, timestamp, direction, price):
        Order.__init__(self, order_id, quantity, broker, timestamp, direction)
        self.price = price

    def signed_price(self):
        if self.direction == Direction.buy.value:
            return +self.price
        else:
            return -self.price

    def __lt__(self, other):
        return (self.signed_price() > other.signed_price()) \
            or (self.signed_price() == other.signed_price()
                   and self.timestamp < other.timestamp)

    def __eq__(self, other):
        return (self.price == other.price) \
            and (self.timestamp == other.timestamp)

    def __gt__(self, other):
        return not (self.__lt__(other) or self.__eq__(other))

    def __str__(self):
        return "(" \
               "order_id: %s, quantity: %d, " \
               "broker: %s, timestamp: %d, " \
               "direction: %d, price: %8.2f" \
               ")" % \
               (self.order_id, self.quantity, self.broker, self.timestamp, self.direction, self.price)


    def set_quantity(self, value):
        self.quantity = value

# %%
class OrderBook(object):
    def __init__(self):
        self.bids = [] # empty list
        self.asks = [] # empty list
        # you use these lists to create priority queues.
        # you need priority queues to access to the top element in O(1)
        self.order_index = dict()
        # you need a dictionary or a unordered Hash map to access any element in O(1)
        # Based on a key which is the order_id
        # insertion time complexity

    def add(self, lo):
        if lo.direction == Direction.buy.value:
            print("A new bid is added. "
                  "(" \
               "order_id: %s, quantity: %d, " \
               "broker: %s, price: %8.2f" \
               ")" % \
                (lo.order_id, lo.quantity, lo.broker, lo.price)
)
            heapq.heappush(self.bids, lo)
            self.order_index[ lo.order_id ] = lo
        else:
            heapq.heappush(self.asks, lo)
            print("A new ask is added. "
                  "(" \
               "order_id: %s, quantity: %d, " \
               "broker: %s, price: %8.2f" \
               ")" % \
                (lo.order_id, lo.quantity, lo.broker, lo.price))
            self.order_index[ lo.order_id ] = lo
        if self.asks and self.bids:
            self.__match()

    def __match(self):
        best_bid = self.bids[0]
        best_ask = self.asks[0]
        if best_bid.price >= best_ask.price:
            if best_bid.quantity > best_ask.quantity:
                remain = best_bid.quantity - best_ask.quantity
                print('A bid (ID: %s) and an ask (ID: %s) are matched. '
                      'The ask (ID: %s) is filled with the quantity %d.' \
                      % (best_bid.order_id, best_ask.order_id, best_ask.order_id, best_ask.quantity))
                self.bids[0].set_quantity(remain)
                heapq.heappop(self.asks)
                self.__match()

            elif best_bid.quantity < best_ask.quantity:
                remain = best_ask.quantity - best_bid.quantity
                print('A bid (ID: %s) and an ask (ID: %s) are matched. '
                      'The bid (ID: %s) is filled with the quantity %d.' \
                      % (best_bid.order_id, best_ask.order_id, best_bid.order_id, best_bid.quantity))
                self.asks[0].set_quantity(remain)
                heapq.heappop(self.bids)
                self.__match()

            else:
                print('A bid (ID: %s) and an ask (ID: %s) are matched. '
                      'Both are filled with the quantity %d.' \
                      % (best_bid.order_id, best_ask.order_id, best_ask.quantity))
                heapq.heappop(self.bids)
                heapq.heappop(self.asks)

# %%
orders = [LimitOrder('1019', 62, 'L', 1, 1, 10702),
LimitOrder('1006', 8, 'R',1, 1, 10665),
LimitOrder('1004', 74, 'C', 2, 0, 9092),
LimitOrder('1012', 92, 'H', 2, 1, 9684),
LimitOrder('1005', 83, 'X', 4, 1, 9841),
LimitOrder('1017', 89, 'D', 5, 1, 9784),
LimitOrder('1001', 40, 'R', 5, 0, 9521),
LimitOrder('1007', 19, 'N', 5, 1, 10388),
LimitOrder('1013', 97, 'J', 6, 0, 9147),
LimitOrder('1010', 41, 'R', 7, 0, 10572),
LimitOrder('1015', 94, 'G', 8, 0, 10077),
LimitOrder('1003', 91, 'Q', 8, 1, 8695),
LimitOrder('1009', 59, 'S', 10, 0, 11066),
LimitOrder('1018', 68, 'F', 12, 0, 8225),
LimitOrder('1008', 3, 'K', 12, 1, 9849),
LimitOrder('1016', 4, 'D', 13, 0, 8726),
LimitOrder('1002', 83, 'O', 16, 0, 10876),
LimitOrder('1011', 38, 'D', 18, 0, 11142),
LimitOrder('1014', 54, 'Q', 19, 1, 9442),
LimitOrder('1000', 68, 'S', 20, 1, 9287)]

# %%
book = OrderBook()

index = 0
for order in orders:
    print('---------------------------')
    print('Event [' + str(index) + ']: ')
    book.add( order )
    print('---------------------------')
    index += 1

    print('Bid (Buy-side) priority queue:')
    if ( book.bids ):
        for i in book.bids:
            print(i)
    else:
        print('Bid is empty.')

    print('Ask (Sell-side) priority queue:')
    if ( book.asks ):
        for i in book.asks:
            print(i)
    else:
        print('Ask is empty.')

    print('\n')
# Out:
# ---------------------------
# Event [0]:
# A new ask is added. (order_id: 1019, quantity: 62, broker: L, price: 10702.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# Bid is empty.
# Ask (Sell-side) priority queue:
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [1]:
# A new ask is added. (order_id: 1006, quantity: 8, broker: R, price: 10665.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# Bid is empty.
# Ask (Sell-side) priority queue:
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [2]:
# A new bid is added. (order_id: 1004, quantity: 74, broker: C, price:  9092.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# Ask (Sell-side) priority queue:
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [3]:
# A new ask is added. (order_id: 1012, quantity: 92, broker: H, price:  9684.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# Ask (Sell-side) priority queue:
# (order_id: 1012, quantity: 92, broker: H, timestamp: 2, direction: 1, price:  9684.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
#
#
# ---------------------------
# Event [4]:
# A new ask is added. (order_id: 1005, quantity: 83, broker: X, price:  9841.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# Ask (Sell-side) priority queue:
# (order_id: 1012, quantity: 92, broker: H, timestamp: 2, direction: 1, price:  9684.00)
# (order_id: 1005, quantity: 83, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [5]:
# A new ask is added. (order_id: 1017, quantity: 89, broker: D, price:  9784.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# Ask (Sell-side) priority queue:
# (order_id: 1012, quantity: 92, broker: H, timestamp: 2, direction: 1, price:  9684.00)
# (order_id: 1017, quantity: 89, broker: D, timestamp: 5, direction: 1, price:  9784.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1005, quantity: 83, broker: X, timestamp: 4, direction: 1, price:  9841.00)
#
#
# ---------------------------
# Event [6]:
# A new bid is added. (order_id: 1001, quantity: 40, broker: R, price:  9521.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1001, quantity: 40, broker: R, timestamp: 5, direction: 0, price:  9521.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# Ask (Sell-side) priority queue:
# (order_id: 1012, quantity: 92, broker: H, timestamp: 2, direction: 1, price:  9684.00)
# (order_id: 1017, quantity: 89, broker: D, timestamp: 5, direction: 1, price:  9784.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1005, quantity: 83, broker: X, timestamp: 4, direction: 1, price:  9841.00)
#
#
# ---------------------------
# Event [7]:
# A new ask is added. (order_id: 1007, quantity: 19, broker: N, price: 10388.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1001, quantity: 40, broker: R, timestamp: 5, direction: 0, price:  9521.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# Ask (Sell-side) priority queue:
# (order_id: 1012, quantity: 92, broker: H, timestamp: 2, direction: 1, price:  9684.00)
# (order_id: 1017, quantity: 89, broker: D, timestamp: 5, direction: 1, price:  9784.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1005, quantity: 83, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
#
#
# ---------------------------
# Event [8]:
# A new bid is added. (order_id: 1013, quantity: 97, broker: J, price:  9147.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1001, quantity: 40, broker: R, timestamp: 5, direction: 0, price:  9521.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1013, quantity: 97, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# Ask (Sell-side) priority queue:
# (order_id: 1012, quantity: 92, broker: H, timestamp: 2, direction: 1, price:  9684.00)
# (order_id: 1017, quantity: 89, broker: D, timestamp: 5, direction: 1, price:  9784.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1005, quantity: 83, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
#
#
# ---------------------------
# Event [9]:
# A new bid is added. (order_id: 1010, quantity: 41, broker: R, price: 10572.00)
# A bid (ID: 1010) and an ask (ID: 1012) are matched. The bid (ID: 1010) is filled with the quantity 41.
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1001, quantity: 40, broker: R, timestamp: 5, direction: 0, price:  9521.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1013, quantity: 97, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# Ask (Sell-side) priority queue:
# (order_id: 1012, quantity: 51, broker: H, timestamp: 2, direction: 1, price:  9684.00)
# (order_id: 1017, quantity: 89, broker: D, timestamp: 5, direction: 1, price:  9784.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1005, quantity: 83, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
#
#
# ---------------------------
# Event [10]:
# A new bid is added. (order_id: 1015, quantity: 94, broker: G, price: 10077.00)
# A bid (ID: 1015) and an ask (ID: 1012) are matched. The ask (ID: 1012) is filled with the quantity 51.
# A bid (ID: 1015) and an ask (ID: 1017) are matched. The bid (ID: 1015) is filled with the quantity 43.
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1001, quantity: 40, broker: R, timestamp: 5, direction: 0, price:  9521.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1013, quantity: 97, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# Ask (Sell-side) priority queue:
# (order_id: 1017, quantity: 46, broker: D, timestamp: 5, direction: 1, price:  9784.00)
# (order_id: 1005, quantity: 83, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
#
#
# ---------------------------
# Event [11]:
# A new ask is added. (order_id: 1003, quantity: 91, broker: Q, price:  8695.00)
# A bid (ID: 1001) and an ask (ID: 1003) are matched. The bid (ID: 1001) is filled with the quantity 40.
# A bid (ID: 1013) and an ask (ID: 1003) are matched. The ask (ID: 1003) is filled with the quantity 51.
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# Ask (Sell-side) priority queue:
# (order_id: 1017, quantity: 46, broker: D, timestamp: 5, direction: 1, price:  9784.00)
# (order_id: 1005, quantity: 83, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
#
#
# ---------------------------
# Event [12]:
# A new bid is added. (order_id: 1009, quantity: 59, broker: S, price: 11066.00)
# A bid (ID: 1009) and an ask (ID: 1017) are matched. The ask (ID: 1017) is filled with the quantity 46.
# A bid (ID: 1009) and an ask (ID: 1005) are matched. The bid (ID: 1009) is filled with the quantity 13.
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# Ask (Sell-side) priority queue:
# (order_id: 1005, quantity: 70, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [13]:
# A new bid is added. (order_id: 1018, quantity: 68, broker: F, price:  8225.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1018, quantity: 68, broker: F, timestamp: 12, direction: 0, price:  8225.00)
# Ask (Sell-side) priority queue:
# (order_id: 1005, quantity: 70, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [14]:
# A new ask is added. (order_id: 1008, quantity: 3, broker: K, price:  9849.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1018, quantity: 68, broker: F, timestamp: 12, direction: 0, price:  8225.00)
# Ask (Sell-side) priority queue:
# (order_id: 1005, quantity: 70, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1008, quantity: 3, broker: K, timestamp: 12, direction: 1, price:  9849.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
#
#
# ---------------------------
# Event [15]:
# A new bid is added. (order_id: 1016, quantity: 4, broker: D, price:  8726.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1018, quantity: 68, broker: F, timestamp: 12, direction: 0, price:  8225.00)
# (order_id: 1016, quantity: 4, broker: D, timestamp: 13, direction: 0, price:  8726.00)
# Ask (Sell-side) priority queue:
# (order_id: 1005, quantity: 70, broker: X, timestamp: 4, direction: 1, price:  9841.00)
# (order_id: 1008, quantity: 3, broker: K, timestamp: 12, direction: 1, price:  9849.00)
# (order_id: 1007, quantity: 19, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
#
#
# ---------------------------
# Event [16]:
# A new bid is added. (order_id: 1002, quantity: 83, broker: O, price: 10876.00)
# A bid (ID: 1002) and an ask (ID: 1005) are matched. The ask (ID: 1005) is filled with the quantity 70.
# A bid (ID: 1002) and an ask (ID: 1008) are matched. The ask (ID: 1008) is filled with the quantity 3.
# A bid (ID: 1002) and an ask (ID: 1007) are matched. The bid (ID: 1002) is filled with the quantity 10.
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1018, quantity: 68, broker: F, timestamp: 12, direction: 0, price:  8225.00)
# (order_id: 1016, quantity: 4, broker: D, timestamp: 13, direction: 0, price:  8726.00)
# Ask (Sell-side) priority queue:
# (order_id: 1007, quantity: 9, broker: N, timestamp: 5, direction: 1, price: 10388.00)
# (order_id: 1006, quantity: 8, broker: R, timestamp: 1, direction: 1, price: 10665.00)
# (order_id: 1019, quantity: 62, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [17]:
# A new bid is added. (order_id: 1011, quantity: 38, broker: D, price: 11142.00)
# A bid (ID: 1011) and an ask (ID: 1007) are matched. The ask (ID: 1007) is filled with the quantity 9.
# A bid (ID: 1011) and an ask (ID: 1006) are matched. The ask (ID: 1006) is filled with the quantity 8.
# A bid (ID: 1011) and an ask (ID: 1019) are matched. The bid (ID: 1011) is filled with the quantity 21.
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1018, quantity: 68, broker: F, timestamp: 12, direction: 0, price:  8225.00)
# (order_id: 1016, quantity: 4, broker: D, timestamp: 13, direction: 0, price:  8726.00)
# Ask (Sell-side) priority queue:
# (order_id: 1019, quantity: 41, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [18]:
# A new ask is added. (order_id: 1014, quantity: 54, broker: Q, price:  9442.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1018, quantity: 68, broker: F, timestamp: 12, direction: 0, price:  8225.00)
# (order_id: 1016, quantity: 4, broker: D, timestamp: 13, direction: 0, price:  8726.00)
# Ask (Sell-side) priority queue:
# (order_id: 1014, quantity: 54, broker: Q, timestamp: 19, direction: 1, price:  9442.00)
# (order_id: 1019, quantity: 41, broker: L, timestamp: 1, direction: 1, price: 10702.00)
#
#
# ---------------------------
# Event [19]:
# A new ask is added. (order_id: 1000, quantity: 68, broker: S, price:  9287.00)
# ---------------------------
# Bid (Buy-side) priority queue:
# (order_id: 1013, quantity: 46, broker: J, timestamp: 6, direction: 0, price:  9147.00)
# (order_id: 1004, quantity: 74, broker: C, timestamp: 2, direction: 0, price:  9092.00)
# (order_id: 1018, quantity: 68, broker: F, timestamp: 12, direction: 0, price:  8225.00)
# (order_id: 1016, quantity: 4, broker: D, timestamp: 13, direction: 0, price:  8726.00)
# Ask (Sell-side) priority queue:
# (order_id: 1000, quantity: 68, broker: S, timestamp: 20, direction: 1, price:  9287.00)
# (order_id: 1019, quantity: 41, broker: L, timestamp: 1, direction: 1, price: 10702.00)
# (order_id: 1014, quantity: 54, broker: Q, timestamp: 19, direction: 1, price:  9442.00)
